# %%
import cv2 as cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('data/img/01.png')
width = 500
height = 500
dim = (width, height)
img_resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
cv2.imwrite("data/img/01.jpg", img)
# Out:
# True

# %% [markdown]
# Tìm hiểu cải thiện ảnh (Image enhancement, improvement) bằng kỹ thuật
# xử lý trên miền thời gian (các phép toán điểm ảnh và biểu đồ) và kỹ thuật xử lý trên
# miền tần số (Phép biến đổi Fourier, phổ của ảnh và bộ lọc số). Cài đặt thử nghiệm
# ứng dụng lọc nhiễu, làm trơn, nâng cao chất lượng ảnh trong các tình huống khác
# nhau và nhận xét
#
# # TÌm hiểu cải thiện ảnh bằng kỹ thuật xử lí trên miền thời gian và miền tần số.
#
# 1. Giới thiệu chung về đề tài
# - xamlol
#
# 2. Các kỹ thuật xử lí trên miền thời gian
# - 2.1 Các phép toán điểm ảnh
# - 2.2 Các phép toán biểu đồ
#
# 3. Các kỹ thuật xử lí trên miền tần số
# - 3.1 Phép biến đổi Fourier
# - 3.2 Phổ của ảnh
# - 3.3 Các bộ lọc số
#
# 4. Cài đặt thử nghiệm
# - Môi trường thử nghiệm
# - Các ví dụ thử nghiệm: Lọc nhiễu, làm trơn, nâng cao chất lượng ảnh
# - Nhận xét

# %%
img = cv2.imread('./data/lenna.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
# Lọc nhiễu 
mask = 1/9*np.array([[1,1,1],[1,1,1],[1,1,1]]).astype(np.uint8)
img_denoise = cv2.filter2D(img,-1,mask)

plt.imshow(img_denoise)
plt.show()

# %%
# Mặt nạ 
mask2 = np.array([[0,0,0],[1,1,1],[0,1,0]]).astype(np.uint8)

# phép lọc max (lọc giãn, lọc dilation)
x2_filter_max = cv2.morphologyEx(x2, cv2.MORPH_DILATE, mask2);

plt.subplot(131),plt.imshow(x2),plt.title('Ảnh gốc x2')
plt.subplot(132),plt.imshow(mask2),plt.title('Mặt nạ')
plt.subplot(133),plt.imshow(x2_filter_max),plt.title('Ảnh lọc max x2')

plt.show()

print('Trước khi lọc max: \n',x2)
print('Mặt nạ: \n',mask2)
print('Sau khi lọc max: \n',x2_filter_max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fe7b9430e360> in <module>
#       3
#       4 # phép lọc max (lọc giãn, lọc dilation)
# ----> 5 x2_filter_max = cv2.morphologyEx(x2, cv2.MORPH_DILATE, mask2);
#       6
#       7 plt.subplot(131),plt.imshow(x2),plt.title('Ảnh gốc x2')
#
# NameError: name 'x2' is not defined
